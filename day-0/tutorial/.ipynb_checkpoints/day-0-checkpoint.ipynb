# %% [markdown]
# # Day 0 — One-State LangGraph with MLflow Gateway
#
# Before running this notebook, complete the environment, MLflow, API-key, and gateway-endpoint setup in `README.md`.

# %% [markdown]
# ## 1. Connect through MLflow Gateway

# %%
from langchain_openai import ChatOpenAI

GATEWAY_URL = "http://127.0.0.1:5001/gateway/mlflow/v1"
GATEWAY_API_KEY = "not-needed"
GATEWAY_ENDPOINT = "workshop-gemini"

llm = ChatOpenAI(
    base_url=GATEWAY_URL,
    api_key=GATEWAY_API_KEY,
    model=GATEWAY_ENDPOINT,
)

reply = llm.invoke("Say: MLflow Gateway is working")
print(reply.content)
# Out:
# MLflow Gateway is working! If you have any specific questions or need assistance with it, feel free to ask!

# %% [markdown]
# ## 2. Build and print the graph

# %%
from typing import TypedDict
from langgraph.graph import START, END, StateGraph

class State(TypedDict):
    user_input: str
    ai_reply: str

def call_ai(state: State):
    reply = llm.invoke(state["user_input"])
    return {"ai_reply": reply.content}

builder = StateGraph(State)
builder.add_node("call_ai", call_ai)
builder.add_edge(START, "call_ai")
builder.add_edge("call_ai", END)
graph = builder.compile()

print(graph.get_graph().draw_ascii())
# Out:
# +-----------+
# | __start__ |
# +-----------+
#       *
#       *
#       *
#  +---------+
#  | call_ai |
#  +---------+
#       *
#       *
#       *
#  +---------+
#  | __end__ |
#  +---------+

# %% [markdown]
# ## 3. Test the input and output

# %%
user_input = "Write a python code to check if a number is prime"
result = graph.invoke({"user_input": user_input})
print("AI:", result["ai_reply"])
# Out:
# AI: You can check if a number is prime in Python using the following function:
#
# ```python
# def is_prime(num):
#     """Check if a number is prime."""
#     if num <= 1:
#         return False
#     elif num <= 3:
#         return True
#     elif num % 2 == 0 or num % 3 == 0:
#         return False
#
#     i = 5
#     while i * i <= num:
#         if num % i == 0 or num % (i + 2) == 0:
#             return False
#         i += 6
#
#     return True
#
# # Example usage:
# number = int(input("Enter a number: "))
# if is_prime(number):
#     print(f"{number} is a prime number.")
# else:
#     print(f"{number} is not a prime number.")
# ```
#
# ### Explanation:
#
# 1. **Initial Checks**:
#    - Any number less than or equal to 1 is not prime.
#    - The numbers 2 and 3 are prime numbers.
#
# 2. **Even Number Check**:
#    - If the number is divisible by 2 or 3, it’s not prime.
#
# 3. **Advanced Checks**:
# ...
